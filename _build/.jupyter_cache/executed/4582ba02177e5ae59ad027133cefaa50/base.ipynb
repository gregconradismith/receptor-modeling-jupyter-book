# %%
print(2 + 2)
# Out:
# 4

# %%
G=graphs.CycleGraph(3); G.add_edge(2,3); G.show(); G.show(edge_labels=False)
# Out:
# Graphics object consisting of 9 graphics primitives
# Graphics object consisting of 9 graphics primitives
