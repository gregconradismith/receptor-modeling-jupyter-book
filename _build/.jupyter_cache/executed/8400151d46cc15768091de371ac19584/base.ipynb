# %%
# %run MyTools.ipynb

# %%
G=graphs.HouseGraph()
G.show(figsize=4,graph_border=True)
# Out:
# Graphics object consisting of 13 graphics primitives

# %%
(G, T, KappaEta, A) = enumerate_allosteric_parameters(G,method='alpha',show=True)
# Out:
# Graphics object consisting of 12 graphics primitives
# Graphics object consisting of 14 graphics primitives
#   1   2*kappa_b          2*kappa_c                  2*kappa_c*kappa_d                            2*kappa_c*kappa_d*kappa_e
#   0   kappa_b^2*eta_bb   2*kappa_b*kappa_c*eta_bc   2*kappa_b*kappa_c*kappa_d*eta_bc*eta_bd      2*kappa_b*kappa_c*kappa_d*kappa_e*eta_bc*eta_bd*eta_be
#   0   0                  kappa_c^2*eta_cc           2*kappa_c^2*kappa_d*eta_cc*eta_cd            2*kappa_c^2*kappa_d*kappa_e*eta_cc*eta_cd*eta_ce
#   0   0                  0                          kappa_c^2*kappa_d^2*eta_cc*eta_cd^2*eta_dd   2*kappa_c^2*kappa_d^2*kappa_e*eta_cc*eta_cd^2*eta_dd*eta_ce*eta_de
#   0   0                  0                          0                                            kappa_c^2*kappa_d^2*kappa_e^2*eta_cc*eta_cd^2*eta_dd*eta_ce^2*eta_de^2*eta_ee

# %%
G=graphs.GridGraph([2,2,2])
G.show(figsize=6,graph_border=True,vertex_size=2000)
# Out:
# Graphics object consisting of 22 graphics primitives

# %%
G=G.canonical_label()
G.show(figsize=6,graph_border=True)
# Out:
# Graphics object consisting of 22 graphics primitives

# %%
(G, T, KappaEta, A) = enumerate_allosteric_parameters(G,method='alpha',show=True)
# Out:
# Graphics object consisting of 21 graphics primitives
# Graphics object consisting of 23 graphics primitives
#   1   2*kappa_b          2*kappa_c                  2*kappa_d                  2*kappa_c*kappa_e                            2*kappa_d*kappa_f                                               2*kappa_d*kappa_g                                               2*kappa_d*kappa_g*kappa_h
#   0   kappa_b^2*eta_bb   2*kappa_b*kappa_c*eta_bc   2*kappa_b*kappa_d*eta_bd   2*kappa_b*kappa_c*kappa_e*eta_bc*eta_be      2*kappa_b*kappa_d*kappa_f*eta_bd*eta_bf                         2*kappa_b*kappa_d*kappa_g*eta_bd*eta_bg                         2*kappa_b*kappa_d*kappa_g*kappa_h*eta_bd*eta_bg*eta_bh
#   0   0                  kappa_c^2*eta_cc           2*kappa_c*kappa_d*eta_cd   2*kappa_c^2*kappa_e*eta_cc*eta_ce            2*kappa_c*kappa_d*kappa_f*eta_cd*eta_cf                         2*kappa_c*kappa_d*kappa_g*eta_cd*eta_cg                         2*kappa_c*kappa_d*kappa_g*kappa_h*eta_cd*eta_cg*eta_ch
#   0   0                  0                          kappa_d^2*eta_dd           2*kappa_c*kappa_d*kappa_e*eta_cd*eta_de      2*kappa_d^2*kappa_f*eta_dd*eta_df                               2*kappa_d^2*kappa_g*eta_dd*eta_dg                               2*kappa_d^2*kappa_g*kappa_h*eta_dd*eta_dg*eta_dh
#   0   0                  0                          0                          kappa_c^2*kappa_e^2*eta_cc*eta_ce^2*eta_ee   2*kappa_c*kappa_d*kappa_e*kappa_f*eta_cd*eta_de*eta_cf*eta_ef   2*kappa_c*kappa_d*kappa_e*kappa_g*eta_cd*eta_de*eta_cg*eta_eg   2*kappa_c*kappa_d*kappa_e*kappa_g*kappa_h*eta_cd*eta_de*eta_cg*eta_eg*eta_ch*eta_eh
#   0   0                  0                          0                          0                                            kappa_d^2*kappa_f^2*eta_dd*eta_df^2*eta_ff                      2*kappa_d^2*kappa_f*kappa_g*eta_dd*eta_df*eta_dg*eta_fg         2*kappa_d^2*kappa_f*kappa_g*kappa_h*eta_dd*eta_df*eta_dg*eta_fg*eta_dh*eta_fh
#   0   0                  0                          0                          0                                            0                                                               kappa_d^2*kappa_g^2*eta_dd*eta_dg^2*eta_gg                      2*kappa_d^2*kappa_g^2*kappa_h*eta_dd*eta_dg^2*eta_gg*eta_dh*eta_gh
#   0   0                  0                          0                          0                                            0                                                               0                                                               kappa_d^2*kappa_g^2*kappa_h^2*eta_dd*eta_dg^2*eta_gg*eta_dh^2*eta_gh^2*eta_hh

# %%
(G, T, KappaEta, A) = enumerate_allosteric_parameters(graphs.PetersenGraph(),method='integer',show=False)

# %%
A.inject_variables()
# Out:
# Defining kappa_1, kappa_2, kappa_3, kappa_4, kappa_5, kappa_6, kappa_7, kappa_8, kappa_9, eta_11, eta_12, eta_22, eta_13, eta_23, eta_33, eta_14, eta_24, eta_34, eta_44, eta_15, eta_25, eta_35, eta_45, eta_55, eta_16, eta_26, eta_36, eta_46, eta_56, eta_66, eta_17, eta_27, eta_37, eta_47, eta_57, eta_67, eta_77, eta_18, eta_28, eta_38, eta_48, eta_58, eta_68, eta_78, eta_88, eta_19, eta_29, eta_39, eta_49, eta_59, eta_69, eta_79, eta_89, eta_99

# %%
T.show(figsize=6,graph_border=True,edge_labels=True)
# Out:
# Graphics object consisting of 30 graphics primitives

# %%
from IPython.display import display, Math
for i,k in enumerate(flatten(KappaEta)):
    if k != 0:
        display(Math(latex(i)+latex(': ')+latex(k)))
# Out:
# $\displaystyle 0 \text{\texttt{:{ }}} 1$
# $\displaystyle 1 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}$
# $\displaystyle 2 \text{\texttt{:{ }}} 2 \kappa_{\mathit{4}}$
# $\displaystyle 3 \text{\texttt{:{ }}} 2 \kappa_{\mathit{5}}$
# $\displaystyle 4 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{2}}$
# $\displaystyle 5 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{6}}$
# $\displaystyle 6 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{2}} \kappa_{\mathit{3}}$
# $\displaystyle 7 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{6}} \kappa_{\mathit{9}}$
# $\displaystyle 8 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{6}} \kappa_{\mathit{7}} \kappa_{\mathit{9}}$
# $\displaystyle 9 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{8}}$
# $\displaystyle 11 \text{\texttt{:{ }}} \kappa_{\mathit{1}}^{2} \eta_{\mathit{11}}$
# $\displaystyle 12 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{4}} \eta_{\mathit{14}}$
# $\displaystyle 13 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{5}} \eta_{\mathit{15}}$
# $\displaystyle 14 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \eta_{\mathit{11}} \eta_{\mathit{12}}$
# $\displaystyle 15 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{6}} \eta_{\mathit{11}} \eta_{\mathit{16}}$
# $\displaystyle 16 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \eta_{\mathit{11}} \eta_{\mathit{12}} \eta_{\mathit{13}}$
# $\displaystyle 17 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{6}} \kappa_{\mathit{9}} \eta_{\mathit{11}} \eta_{\mathit{16}} \eta_{\mathit{19}}$
# $\displaystyle 18 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{6}} \kappa_{\mathit{7}} \kappa_{\mathit{9}} \eta_{\mathit{11}} \eta_{\mathit{16}} \eta_{\mathit{17}} \eta_{\mathit{19}}$
# $\displaystyle 19 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{8}} \eta_{\mathit{11}} \eta_{\mathit{12}} \eta_{\mathit{13}} \eta_{\mathit{18}}$
# $\displaystyle 22 \text{\texttt{:{ }}} \kappa_{\mathit{4}}^{2} \eta_{\mathit{44}}$
# $\displaystyle 23 \text{\texttt{:{ }}} 2 \kappa_{\mathit{4}} \kappa_{\mathit{5}} \eta_{\mathit{45}}$
# $\displaystyle 24 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{2}} \kappa_{\mathit{4}} \eta_{\mathit{14}} \eta_{\mathit{24}}$
# $\displaystyle 25 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{4}} \kappa_{\mathit{6}} \eta_{\mathit{14}} \eta_{\mathit{46}}$
# $\displaystyle 26 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{4}} \eta_{\mathit{14}} \eta_{\mathit{24}} \eta_{\mathit{34}}$
# $\displaystyle 27 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{4}} \kappa_{\mathit{6}} \kappa_{\mathit{9}} \eta_{\mathit{14}} \eta_{\mathit{46}} \eta_{\mathit{49}}$
# $\displaystyle 28 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{4}} \kappa_{\mathit{6}} \kappa_{\mathit{7}} \kappa_{\mathit{9}} \eta_{\mathit{14}} \eta_{\mathit{46}} \eta_{\mathit{47}} \eta_{\mathit{49}}$
# $\displaystyle 29 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{4}} \kappa_{\mathit{8}} \eta_{\mathit{14}} \eta_{\mathit{24}} \eta_{\mathit{34}} \eta_{\mathit{48}}$
# $\displaystyle 33 \text{\texttt{:{ }}} \kappa_{\mathit{5}}^{2} \eta_{\mathit{55}}$
# $\displaystyle 34 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{2}} \kappa_{\mathit{5}} \eta_{\mathit{15}} \eta_{\mathit{25}}$
# $\displaystyle 35 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{5}} \kappa_{\mathit{6}} \eta_{\mathit{15}} \eta_{\mathit{56}}$
# $\displaystyle 36 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{5}} \eta_{\mathit{15}} \eta_{\mathit{25}} \eta_{\mathit{35}}$
# $\displaystyle 37 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{5}} \kappa_{\mathit{6}} \kappa_{\mathit{9}} \eta_{\mathit{15}} \eta_{\mathit{56}} \eta_{\mathit{59}}$
# $\displaystyle 38 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{5}} \kappa_{\mathit{6}} \kappa_{\mathit{7}} \kappa_{\mathit{9}} \eta_{\mathit{15}} \eta_{\mathit{56}} \eta_{\mathit{57}} \eta_{\mathit{59}}$
# $\displaystyle 39 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{5}} \kappa_{\mathit{8}} \eta_{\mathit{15}} \eta_{\mathit{25}} \eta_{\mathit{35}} \eta_{\mathit{58}}$
# $\displaystyle 44 \text{\texttt{:{ }}} \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}}^{2} \eta_{\mathit{11}} \eta_{\mathit{12}}^{2} \eta_{\mathit{22}}$
# $\displaystyle 45 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \kappa_{\mathit{6}} \eta_{\mathit{11}} \eta_{\mathit{12}} \eta_{\mathit{16}} \eta_{\mathit{26}}$
# $\displaystyle 46 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}}^{2} \kappa_{\mathit{3}} \eta_{\mathit{11}} \eta_{\mathit{12}}^{2} \eta_{\mathit{22}} \eta_{\mathit{13}} \eta_{\mathit{23}}$
# $\displaystyle 47 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \kappa_{\mathit{6}} \kappa_{\mathit{9}} \eta_{\mathit{11}} \eta_{\mathit{12}} \eta_{\mathit{16}} \eta_{\mathit{26}} \eta_{\mathit{19}} \eta_{\mathit{29}}$
# $\displaystyle 48 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \kappa_{\mathit{6}} \kappa_{\mathit{7}} \kappa_{\mathit{9}} \eta_{\mathit{11}} \eta_{\mathit{12}} \eta_{\mathit{16}} \eta_{\mathit{26}} \eta_{\mathit{17}} \eta_{\mathit{27}} \eta_{\mathit{19}} \eta_{\mathit{29}}$
# $\displaystyle 49 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}}^{2} \kappa_{\mathit{3}} \kappa_{\mathit{8}} \eta_{\mathit{11}} \eta_{\mathit{12}}^{2} \eta_{\mathit{22}} \eta_{\mathit{13}} \eta_{\mathit{23}} \eta_{\mathit{18}} \eta_{\mathit{28}}$
# $\displaystyle 55 \text{\texttt{:{ }}} \kappa_{\mathit{1}}^{2} \kappa_{\mathit{6}}^{2} \eta_{\mathit{11}} \eta_{\mathit{16}}^{2} \eta_{\mathit{66}}$
# $\displaystyle 56 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{6}} \eta_{\mathit{11}} \eta_{\mathit{12}} \eta_{\mathit{13}} \eta_{\mathit{16}} \eta_{\mathit{26}} \eta_{\mathit{36}}$
# $\displaystyle 57 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{6}}^{2} \kappa_{\mathit{9}} \eta_{\mathit{11}} \eta_{\mathit{16}}^{2} \eta_{\mathit{66}} \eta_{\mathit{19}} \eta_{\mathit{69}}$
# $\displaystyle 58 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{6}}^{2} \kappa_{\mathit{7}} \kappa_{\mathit{9}} \eta_{\mathit{11}} \eta_{\mathit{16}}^{2} \eta_{\mathit{66}} \eta_{\mathit{17}} \eta_{\mathit{67}} \eta_{\mathit{19}} \eta_{\mathit{69}}$
# $\displaystyle 59 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{6}} \kappa_{\mathit{8}} \eta_{\mathit{11}} \eta_{\mathit{12}} \eta_{\mathit{13}} \eta_{\mathit{16}} \eta_{\mathit{26}} \eta_{\mathit{36}} \eta_{\mathit{18}} \eta_{\mathit{68}}$
# $\displaystyle 66 \text{\texttt{:{ }}} \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}}^{2} \kappa_{\mathit{3}}^{2} \eta_{\mathit{11}} \eta_{\mathit{12}}^{2} \eta_{\mathit{22}} \eta_{\mathit{13}}^{2} \eta_{\mathit{23}}^{2} \eta_{\mathit{33}}$
# $\displaystyle 67 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{6}} \kappa_{\mathit{9}} \eta_{\mathit{11}} \eta_{\mathit{12}} \eta_{\mathit{13}} \eta_{\mathit{16}} \eta_{\mathit{26}} \eta_{\mathit{36}} \eta_{\mathit{19}} \eta_{\mathit{29}} \eta_{\mathit{39}}$
# $\displaystyle 68 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{6}} \kappa_{\mathit{7}} \kappa_{\mathit{9}} \eta_{\mathit{11}} \eta_{\mathit{12}} \eta_{\mathit{13}} \eta_{\mathit{16}} \eta_{\mathit{26}} \eta_{\mathit{36}} \eta_{\mathit{17}} \eta_{\mathit{27}} \eta_{\mathit{37}} \eta_{\mathit{19}} \eta_{\mathit{29}} \eta_{\mathit{39}}$
# $\displaystyle 69 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}}^{2} \kappa_{\mathit{3}}^{2} \kappa_{\mathit{8}} \eta_{\mathit{11}} \eta_{\mathit{12}}^{2} \eta_{\mathit{22}} \eta_{\mathit{13}}^{2} \eta_{\mathit{23}}^{2} \eta_{\mathit{33}} \eta_{\mathit{18}} \eta_{\mathit{28}} \eta_{\mathit{38}}$
# $\displaystyle 77 \text{\texttt{:{ }}} \kappa_{\mathit{1}}^{2} \kappa_{\mathit{6}}^{2} \kappa_{\mathit{9}}^{2} \eta_{\mathit{11}} \eta_{\mathit{16}}^{2} \eta_{\mathit{66}} \eta_{\mathit{19}}^{2} \eta_{\mathit{69}}^{2} \eta_{\mathit{99}}$
# $\displaystyle 78 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{6}}^{2} \kappa_{\mathit{7}} \kappa_{\mathit{9}}^{2} \eta_{\mathit{11}} \eta_{\mathit{16}}^{2} \eta_{\mathit{66}} \eta_{\mathit{17}} \eta_{\mathit{67}} \eta_{\mathit{19}}^{2} \eta_{\mathit{69}}^{2} \eta_{\mathit{79}} \eta_{\mathit{99}}$
# $\displaystyle 79 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{6}} \kappa_{\mathit{8}} \kappa_{\mathit{9}} \eta_{\mathit{11}} \eta_{\mathit{12}} \eta_{\mathit{13}} \eta_{\mathit{16}} \eta_{\mathit{26}} \eta_{\mathit{36}} \eta_{\mathit{18}} \eta_{\mathit{68}} \eta_{\mathit{19}} \eta_{\mathit{29}} \eta_{\mathit{39}} \eta_{\mathit{89}}$
# $\displaystyle 88 \text{\texttt{:{ }}} \kappa_{\mathit{1}}^{2} \kappa_{\mathit{6}}^{2} \kappa_{\mathit{7}}^{2} \kappa_{\mathit{9}}^{2} \eta_{\mathit{11}} \eta_{\mathit{16}}^{2} \eta_{\mathit{66}} \eta_{\mathit{17}}^{2} \eta_{\mathit{67}}^{2} \eta_{\mathit{77}} \eta_{\mathit{19}}^{2} \eta_{\mathit{69}}^{2} \eta_{\mathit{79}}^{2} \eta_{\mathit{99}}$
# $\displaystyle 89 \text{\texttt{:{ }}} 2 \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}} \kappa_{\mathit{3}} \kappa_{\mathit{6}} \kappa_{\mathit{7}} \kappa_{\mathit{8}} \kappa_{\mathit{9}} \eta_{\mathit{11}} \eta_{\mathit{12}} \eta_{\mathit{13}} \eta_{\mathit{16}} \eta_{\mathit{26}} \eta_{\mathit{36}} \eta_{\mathit{17}} \eta_{\mathit{27}} \eta_{\mathit{37}} \eta_{\mathit{18}} \eta_{\mathit{68}} \eta_{\mathit{78}} \eta_{\mathit{19}} \eta_{\mathit{29}} \eta_{\mathit{39}} \eta_{\mathit{89}}$
# $\displaystyle 99 \text{\texttt{:{ }}} \kappa_{\mathit{1}}^{2} \kappa_{\mathit{2}}^{2} \kappa_{\mathit{3}}^{2} \kappa_{\mathit{8}}^{2} \eta_{\mathit{11}} \eta_{\mathit{12}}^{2} \eta_{\mathit{22}} \eta_{\mathit{13}}^{2} \eta_{\mathit{23}}^{2} \eta_{\mathit{33}} \eta_{\mathit{18}}^{2} \eta_{\mathit{28}}^{2} \eta_{\mathit{38}}^{2} \eta_{\mathit{88}}$
