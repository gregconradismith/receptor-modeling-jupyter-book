# %%
var('a12, a21, a13, a31, a23, a32, a34, a43')
d = {1: {2:a12, 3:a13}, 2: {1:a21, 3:a23}, 3: {2:a32, 1:a31, 4:a34}, 4: {3:a43}};
G = DiGraph(d,weighted=True)
vertex_positions = {1: (0, 0), 2: (1, 1.41), 3: (2, 0), 4: (4,0)}
G.plot(figsize=8,edge_labels=True,pos=vertex_positions,graph_border=True)
# Out:
# Graphics object consisting of 25 graphics primitives

# %%
A = G.weighted_adjacency_matrix()
print(A)
# Out:
# [  0 a12 a13   0]
# [a21   0 a23   0]
# [a31 a32   0 a34]
# [  0   0 a43   0]

# %%
Q = A - diagonal_matrix(sum(A.T))
print(Q)
# Out:
# [      -a12 - a13              a12              a13                0]
# [             a21       -a21 - a23              a23                0]
# [             a31              a32 -a31 - a32 - a34              a34]
# [               0                0              a43             -a43]

# %%
e = matrix([1,1,1,1]).T
print(Q*e)
# Out:
# [0]
# [0]
# [0]
# [0]

# %%
var('p1 p2 p3 p4')
p = vector([p1, p2, p3, p4])
pQ = p*Q
eq =[]
for lhs in pQ:
    print(lhs == 0)
    eq.append(lhs == 0)
# Out:
# -(a12 + a13)*p1 + a21*p2 + a31*p3 == 0
# a12*p1 - (a21 + a23)*p2 + a32*p3 == 0
# a13*p1 + a23*p2 - (a31 + a32 + a34)*p3 + a43*p4 == 0
# a34*p3 - a43*p4 == 0

# %%
print(Q.rank())
# Out:
# 0

# %%
eq[-1] = p1+p2+p3+p4 == 1
for q in eq:
    print(q)
# Out:
# -(a12 + a13)*p1 + a21*p2 + a31*p3 == 0
# a12*p1 - (a21 + a23)*p2 + a32*p3 == 0
# a13*p1 + a23*p2 - (a31 + a32 + a34)*p3 + a43*p4 == 0
# p1 + p2 + p3 + p4 == 1

# %%
z = solve(eq,list(p))
for i in range(4):
    f = z[0][i].rhs()
    print('p%s' % i,'=',f.expand().factor())
# Out:
# p0 = (a21*a31 + a23*a31 + a21*a32)*a43/(a13*a21*a34 + a12*a23*a34 + a13*a23*a34 + a13*a21*a43 + a12*a23*a43 + a13*a23*a43 + a12*a31*a43 + a21*a31*a43 + a23*a31*a43 + a12*a32*a43 + a13*a32*a43 + a21*a32*a43)
# p1 = (a12*a31 + a12*a32 + a13*a32)*a43/(a13*a21*a34 + a12*a23*a34 + a13*a23*a34 + a13*a21*a43 + a12*a23*a43 + a13*a23*a43 + a12*a31*a43 + a21*a31*a43 + a23*a31*a43 + a12*a32*a43 + a13*a32*a43 + a21*a32*a43)
# p2 = (a13*a21 + a12*a23 + a13*a23)*a43/(a13*a21*a34 + a12*a23*a34 + a13*a23*a34 + a13*a21*a43 + a12*a23*a43 + a13*a23*a43 + a12*a31*a43 + a21*a31*a43 + a23*a31*a43 + a12*a32*a43 + a13*a32*a43 + a21*a32*a43)
# p3 = (a13*a21 + a12*a23 + a13*a23)*a34/(a13*a21*a34 + a12*a23*a34 + a13*a23*a34 + a13*a21*a43 + a12*a23*a43 + a13*a23*a43 + a12*a31*a43 + a21*a31*a43 + a23*a31*a43 + a12*a32*a43 + a13*a32*a43 + a21*a32*a43)

# %%
def mysolve(p,Q):
    pQ = p*Q
    eq =[]
    for lhs in pQ:
       eq.append(lhs == 0)
    eq[-1] = p1+p2+p3+p4 == 1
    z = solve(eq,list(p))
    for i in range(4):
        f = z[0][i].rhs()
        print('p%s' % i,'=',f.expand().factor())

# %%
Q = Q.subs(a12=a13*a32*a21/(a23*a31))
mysolve(p,Q)
# Out:
# p0 = a23*a31*a43/(a13*a23*a34 + a13*a23*a43 + a23*a31*a43 + a13*a32*a43)
# p1 = a13*a32*a43/(a13*a23*a34 + a13*a23*a43 + a23*a31*a43 + a13*a32*a43)
# p2 = a13*a23*a43/(a13*a23*a34 + a13*a23*a43 + a23*a31*a43 + a13*a32*a43)
# p3 = a13*a23*a34/(a13*a23*a34 + a13*a23*a43 + a23*a31*a43 + a13*a32*a43)
