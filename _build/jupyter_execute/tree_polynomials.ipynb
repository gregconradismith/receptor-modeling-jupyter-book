# %% [markdown]
# # Reduced Graph Powers
#
# This is a toolbox of functions to help with understanding reduced power graphs and tree polynomials.

# %%
# %run MyTools.ipynb

# %% [markdown]
# Tree polynomials

# %%
G = graphs.HouseGraph()
G = add_edge_monomials(G)
G.show(figsize=3,edge_labels=true)
# Out:
# Graphics object consisting of 18 graphics primitives

# %%
L=combinatorial_laplacian(G)
print(L)
# Out:
# [      e01 + e02            -e01            -e02               0               0]
# [           -e01       e01 + e13               0            -e13               0]
# [           -e02               0 e02 + e23 + e24            -e23            -e24]
# [              0            -e13            -e23 e13 + e23 + e34            -e34]
# [              0               0            -e24            -e34       e24 + e34]

# %%
T=tree_polynomial(G)
print(T)
# Out:
# e01*e02*e13*e24 + e01*e02*e23*e24 + e01*e13*e23*e24 + e02*e13*e23*e24 + e01*e02*e13*e34 + e01*e02*e23*e34 + e01*e13*e23*e34 + e02*e13*e23*e34 + e01*e02*e24*e34 + e01*e13*e24*e34 + e02*e13*e24*e34

# %%
G=graphs.WheelGraph(4)
D = symmetric_directed(G)
D = add_edge_monomials(D)
D.show(figsize=6,edge_labels=true)
print(tree_polynomial(D))
# Out:
# Graphics object consisting of 32 graphics primitives
# e10*e20*e30 + e12*e20*e30 + e13*e20*e30 + e10*e21*e30 + e13*e21*e30 + e10*e23*e30 + e12*e23*e30 + e13*e23*e30 + e10*e20*e31 + e12*e20*e31 + e10*e21*e31 + e10*e23*e31 + e10*e20*e32 + e12*e20*e32 + e13*e20*e32 + e10*e21*e32

# %% [markdown]
# Constructing reduced graph powers with transitions and contexts as edge labels

# %%
G = graphs.CycleGraph(4)
G = G.canonical_label()
G = add_edge_monomials(G)
G.show(figsize=8,edge_labels=true)
# Out:
# Graphics object consisting of 13 graphics primitives

# %%
Gk=reduced_Cartesian_power(graphs.CycleGraph(4),2,edge_labels='cannonical')
Gk.show(figsize=8,edge_labels=true)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [88], line 1
# ----> 1 Gk=reduced_Cartesian_power(graphs.CycleGraph(Integer(4)),Integer(2),edge_labels='cannonical')
#       2 Gk.show(figsize=Integer(8),edge_labels=true)
#
# File /tmp/ipykernel_4739/3187446973.py:2, in reduced_Cartesian_power(G, k, edge_labels, prefix, independent)
#       1 def reduced_Cartesian_power(G, k, edge_labels='cannonical',prefix='',independent=false):
# ----> 2     Gk = Cartesian_power(G, k, edge_labels)
#       3     for v in Gk.vertices(sort=True):
#       4         for u in Gk.vertices(sort=True):
#
# File /tmp/ipykernel_4739/758290369.py:15, in Cartesian_power(G, k, edge_labels)
#      12 Gk.relabel(vflat)
#      13 if edge_labels=='cannonical':
#      14     #Gk = add_edge_labels_ver2(Gk,edge_labels='cannonical')
# ---> 15     Gk = add_edge_monomials(Gk)
#      16 return Gk
#
# File /tmp/ipykernel_4739/2895485860.py:24, in add_edge_monomials(G, method, edge_vars, ring, short_name)
#      22     for sub in edge_subscripts:
#      23         edge_names.append('e_{\\mathit{' + sub.replace('e','e_') + '}}') # create a list of latex names for the edge variables
# ---> 24     E=PolynomialRing(ZZ,names=edge_vars,order='invlex') # create a polynomial ring using the edge variables
#      25     E._latex_names = edge_names # assign latex names to the polynomial variables
#      26 gen=Integer(0);
#
# File /ext/sage/10.0/src/sage/rings/polynomial/polynomial_ring_constructor.py:678, in PolynomialRing(base_ring, *args, **kwds)
#     675     except KeyError:
#     676         raise TypeError("you must specify the names of the variables")
# --> 678 names = normalize_names(n, names)
#     680 # At this point, we have only handled the "names" keyword if it was
#     681 # needed. Since we know the variable names, it would logically be
#     682 # an error to specify an additional "names" keyword. However,
#    (...)
#     685 # and we allow this for historical reasons. However, the names
#     686 # must be consistent!
#     687 if "names" in kwds:
#
# File /ext/sage/10.0/src/sage/structure/category_object.pyx:900, in sage.structure.category_object.normalize_names()
#     898         return dir_with_other_class(self, self.category().parent_class)
#     899
# --> 900 cpdef normalize_names(Py_ssize_t ngens, names):
#     901     r"""
#     902     Return a tuple of strings of variable names of length ngens given
#
# File /ext/sage/10.0/src/sage/structure/category_object.pyx:1014, in sage.structure.category_object.normalize_names()
#    1012             names = sage.misc.defaults.variable_names(ngens, names)
#    1013
# -> 1014 certify_names(names)
#    1015 if ngens >= 0 and len(names) != ngens:
#    1016     raise IndexError("the number of names must equal the number of generators")
#
# File /ext/sage/10.0/src/sage/structure/category_object.pyx:1064, in sage.structure.category_object.certify_names()
#    1062 if not N.replace("_", "").isalnum():
#    1063     # We must be alphanumeric, but we make an exception for non-leading '_' characters.
# -> 1064     raise ValueError("variable name {!r} is not alphanumeric".format(N))
#    1065 if not N[0].isalpha():
#    1066     raise ValueError("variable name {!r} does not start with a letter".format(N))
#
# ValueError: variable name 'e_(0, 0)(0, 1)' is not alphanumeric

# %%
Gk=reduced_Cartesian_power(graphs.PathGraph(4),3,edge_labels='induced',prefix='a')
Gk.show(figsize=20,edge_labels=true,vertex_size=2000)

# %%
G=graphs.CycleGraph(3)
Gk=reduced_Cartesian_power(G,2,edge_labels='induced',prefix='a',independent=true)
Gk.show(figsize=5,edge_labels=true,vertex_size=0)
print(combinatorial_laplacian(Gk))
print()
Tk=tree_polynomial(Gk); print(Tk)
Tk.factor()

# %%
D = symmetric_directed(graphs.CycleGraph(3))
Dk=reduced_Cartesian_power(D,2,edge_labels='induced',prefix='a',independent=true)
Dk.show(figsize=6,edge_labels=true)
print(combinatorial_laplacian(Dk,combinatorial_coefficients=true))
Tk=tree_polynomial(Dk,combinatorial_coefficients=true)
Tk.factor()

# %%
Gk=reduced_Cartesian_power(graphs.CubeGraph(4),2)
print('There are',Gk.spanning_trees_count(),'spanning trees.  Here is one:')
TGk=Gk.random_spanning_tree()
for e in Gk.edges(sort=True): Gk.set_edge_label(e[0], e[1], 0)
for e in TGk: Gk.set_edge_label(e[0], e[1], 1)
Gk.show(vertex_labels=false,vertex_size=0,figsize=6,edge_colors=Gk._color_by_label({0:'black',1:'cyan'}),layout='circular')

# %%
D = symmetric_directed(graphs.CycleGraph(3))
Dk=reduced_Cartesian_power(D,3,edge_labels='induced',prefix='a',independent=true)
Dk.show(figsize=6,edge_labels=true)
Tk=tree_polynomial(Dk,combinatorial_coefficients=true)
Tk.factor()

# %%
G = graphs.CycleGraph(3)
G.add_vertex()
G.add_edge(2,3)
D = symmetric_directed(G)
D.show(edge_labels=true,layout='spring')
Dk=reduced_Cartesian_power(D,2,edge_labels='induced',prefix='a',independent=true)
Dk.show(figsize=10,edge_labels=true)
Tk=tree_polynomial(Dk,combinatorial_coefficients=true)
Tk.factor()
